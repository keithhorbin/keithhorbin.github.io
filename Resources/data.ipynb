# %%
import pandas as pd

# %%
cities = pd.read_csv("cities.csv")
cities
# Out:
#              City  Cloudiness Country             DateTime  Humidity    Lat  \
# 0         Ushuaia          75      AR  2020-01-27 02:21:31        70 -54.80
# 1     Yerbogachen          90      RU  2020-01-27 02:21:32        91  61.28
# 2          Hobart          75      AU  2020-01-27 02:20:17        42 -42.88
# 3     Port Alfred          18      ZA  2020-01-27 02:21:34        76 -33.59
# 4     Yellowknife          90      CA  2020-01-27 02:21:35        84  62.46
# ..            ...         ...     ...                  ...       ...    ...
# 575      Acapulco          20      MX  2020-01-27 02:29:29        74  16.86
# 576  Magistralnyy         100      RU  2020-01-27 02:33:32        89  56.17
# 577           Edd          22      ER  2020-01-27 02:33:34        72  13.93
# 578        Carmen           5      MX  2020-01-27 02:33:09        83  18.63
# 579         Zabol          82      AF  2020-01-27 02:33:36        97  32.25
#
#         Lng  Max Temp  Wind Speed
# ...

# %%
data = cities.to_html()
print(data)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>DateTime</th>
#       <th>Humidity</th>
#       <th>Lat</th>
#       <th>Lng</th>
#       <th>Max Temp</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Ushuaia</td>
#       <td>75</td>
#       <td>AR</td>
#       <td>2020-01-27 02:21:31</td>
#       <td>70</td>
#       <td>-54.80</td>
#       <td>-68.30</td>
#       <td>48.20</td>
#       <td>5.82</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Yerbogachen</td>
#       <td>90</td>
#       <td>RU</td>
#       <td>2020-01-27 02:21:32</td>
#       <td>91</td>
#       <td>61.28</td>
#       <td>108.01</td>
#       <td>2.48</td>
#       <td>11.90</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Hobart</td>
#       <td>75</td>
#       <td>AU</td>
# ...

# %%
cities.to_html("data.html")
